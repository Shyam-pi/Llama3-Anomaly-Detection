# %% [markdown]
# FINE TUNINING USING UNSLOTH

# %%
import shutil, os, subprocess
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/NIH/')
# Out:
# Mounted at /content/drive

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ...

# %%
import pandas as pd
from pprint import pprint

list_ds =[
{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n04048551113073|Width|Millimeter|10 |\n04048551113073|Length|Millimeter|28 |",
 "output":"PrimaryDI|Width (millimeter)|Length (millimeter)\n04048551113073|10|28"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n04048266179913|Outer Diameter|Micrometer|16|",
 "output":"PrimaryDI|Outer Diameter (millimeter)\n04048551113073|0.016"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n04048266179906|Outer Diameter|Millimeter|14|",
 "output":"PrimaryDI|Outer Diameter (millimeter)\n04048266179906|14"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n04048266179883|Outer Diameter|Millimeter|34|\n04048266179883|Length|Millimeter|70|",
 "output":"PrimaryDI|Outer Diameter (millimeter)|Length (millimeter)\n04048266179906|34|70"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n04048266174758|Lumen/Inner Diameter|Millimeter|10|",
 "output":"PrimaryDI|Inner Diameter (millimeter)\n04048266174758|10"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844856091276|Width|Millimeter|10|\n00844856091276|Height|Millimeter|15|\n00844856091276|Angle|degree|10|",
 "output":"PrimaryDI|Width (millimeter)|Height (millimeter)|Angle (degree)\n00844856091276|10|15|10"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844868033936|Device Size Text, specify|||Diameter 4 Millimeter",
 "output":"PrimaryDI|Diameter (millimeter)\n00844868033936|4"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844868035503|Device Size Text, specify|||Volume 1 mL",
 "output":"PrimaryDI|Volume (mL)\n00844868035503|1"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844868036456|Device Size Text, specify|||Restorative Platform Diameter 5 mm",
 "output":"PrimaryDI|Diameter (millimeter)\n00844868036456|5"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844868040903|Device Size Text, specify|||Emergence Profile Diameter 3.8 Millimeter\n00844868040903|Height|Millimeter|3|",
 "output":"PrimaryDI|Diameter (millimeter)|Height (millimeter)\n00844868036456|3.8|3"},

{"instruction":"First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output",
 "input":"PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n00844868041511|Length|Inch|18|",
 "output":"PrimaryDI|Length (millimeter)\n00844868041511|457.2"},
]

pprint(list_ds)
# Out:
# [{'input': 'PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n'
#            '04048551113073|Width|Millimeter|10 |\n'
#            '04048551113073|Length|Millimeter|28 |',
#   'instruction': 'First row are the headers and subsequent row(s) are the data '
#                  'points corresponding to a certain PrimaryDI. Create a '
#                  'similar dataset, updating headers with corresponding values '
#                  'and units (use millimetres for any length measure, kilograms '
#                  'for weight, mL for volume and degrees for angles). Retain '
#                  "'PrimaryDI' in the output",
#   'output': 'PrimaryDI|Width (millimeter)|Length (millimeter)\n'
#             '04048551113073|10|28'},
#  {'input': 'PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText\n'
#            '04048266179913|Outer Diameter|Micrometer|16|',
#   'instruction': 'First row are the headers and subsequent row(s) are the data '
# ...

# %%
# %%capture
import torch
major_version, minor_version = torch.cuda.get_device_capability()
# Must install separately since Colab has torch 2.2.1, which breaks packages
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # Use this for new GPUs like Ampere, Hopper GPUs (RTX 30xx, RTX 40xx, A100, H100, L40)
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # Use this for older GPUs (V100, Tesla T4, RTX 20xx)
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)

model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj","gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Unsloth 2024.5 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

import datasets
import pandas as pd
# Create a dataset from the array of dictionaries

df = pd.DataFrame(list_ds)
dataset = datasets.Dataset.from_pandas(df)

# Print the dataset
print(dataset)
dataset = dataset.map(formatting_prompts_func, batched = True,)
print(dataset)
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 11
# })
# Map:   0%|          | 0/11 [00:00<?, ? examples/s]
# Dataset({
#     features: ['instruction', 'input', 'output', 'text'],
#     num_rows: 11
# })

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 50,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/11 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 5.605 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 11 | Num Epochs = 50
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 50
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 04:42, Epoch 33/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.383400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.478900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.165000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.121600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.842000</td>
#     </tr>
# ...

# %%
model.save_pretrained_merged("model_nih_v1", tokenizer, save_method = "merged_16bit",)
# Out:
# Unsloth: You have 1 CPUs. Using `safe_serialization` is 10x slower.
# We shall switch to Pytorch saving, which will take 3 minutes and not 30 minutes.
# To force `safe_serialization`, set it to `None` instead.
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 5.7G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 6.21 out of 12.67 RAM for saving.
# ...
# 100%|██████████| 32/32 [00:48<00:00,  1.50s/it]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 5 minutes for Llama-7b...
# Unsloth: Saving model_nih_v1/pytorch_model-00001-of-00004.bin...
# Unsloth: Saving model_nih_v1/pytorch_model-00002-of-00004.bin...
# Unsloth: Saving model_nih_v1/pytorch_model-00003-of-00004.bin...
# Unsloth: Saving model_nih_v1/pytorch_model-00004-of-00004.bin...
# Done.

# %%
data_input = """PrimaryDI|sizeType|size (Unit)|size (Value)|sizeText
00842517100084|Device Size Text, specify|||2.5 cm Width 7.5 cm Length 3mm Thick"""

data_instruction = """First row are the headers and subsequent row(s) are the data points corresponding to a certain PrimaryDI. Create a similar dataset, updating headers with corresponding values and units (use millimetres for any length measure, kilograms for weight, mL for volume and degrees for angles). Retain 'PrimaryDI' in the output"""

temp = alpaca_prompt.format(data_instruction, data_input, "")

# %%
inputs = tokenizer([alpaca_prompt.format(data_instruction, data_input, "")], return_tensors = "pt").to("cuda")
outputs = model.generate(**inputs, max_new_tokens = 90)
tokenizer.batch_decode(outputs)[0][len(temp) + len("L\n\n### Response:\n"): - len("<|end_of_text|>")]
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'PrimaryDI|Diameter (millimeter)|Length (millimeter)\n00846468093211|3.2|115'
